# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#load csv file data with headers

location = "datasets/DC_Properties.csv"
dc_df = pd.read_csv(location)

# %%
dc_df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0  ... -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0  ... -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0  ... -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
dc_df.tail()
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 158952      158952       1          0  Forced Air  Y        NaN      3      1
# 158953      158953       1          0  Forced Air  Y        NaN      4      2
# 158954      158954       2          0  Forced Air  Y        NaN      4      2
# 158955      158955       1          0   Warm Cool  Y        NaN      2      0
# 158956      158956       1          0   Warm Cool  Y        NaN      2      0
#
#            AYB  YR_RMDL  ...  LONGITUDE       ASSESSMENT_NBHD  \
# 158952  1938.0   2006.0  ...  -77.01942            Old City 2
# 158953  1938.0   2006.0  ...  -77.01942            Old City 2
# 158954  1920.0   2007.0  ...  -77.01942            Old City 2
# 158955  1965.0      NaN  ...  -77.01823  Southwest Waterfront
# 158956  1965.0      NaN  ...  -77.01823  Southwest Waterfront
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# ...

# %%
#Selecting rows with no missing age or gender
dc_df.notnull()
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM  HEAT    AC  NUM_UNITS  ROOMS  BEDRM  \
# 0             True    True       True  True  True       True   True   True
# 1             True    True       True  True  True       True   True   True
# 2             True    True       True  True  True       True   True   True
# 3             True    True       True  True  True       True   True   True
# 4             True    True       True  True  True       True   True   True
# 5             True    True       True  True  True       True   True   True
# 6             True    True       True  True  True       True   True   True
# 7             True    True       True  True  True       True   True   True
# 8             True    True       True  True  True       True   True   True
# 9             True    True       True  True  True       True   True   True
# 10            True    True       True  True  True       True   True   True
# ...

# %%
#drops duplicate rows, default is to keep first observation
dup_dc_df = dc_df.drop_duplicates()
dup_dc_df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
dup_dc_df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0  ... -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0  ... -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0  ... -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
# iterating the columns 
for col in dup_dc_df.columns: 
    print(col)
# Out:
# Unnamed: 0
# BATHRM
# HF_BATHRM
# HEAT
# AC
# NUM_UNITS
# ROOMS
# BEDRM
# AYB
# YR_RMDL
# EYB
# STORIES
# SALEDATE
# PRICE
# QUALIFIED
# SALE_NUM
# GBA
# BLDG_NUM
# STYLE
# STRUCT
# GRADE
# CNDTN
# EXTWALL
# ROOF
# INTWALL
# KITCHENS
# FIREPLACES
# USECODE
# LANDAREA
# GIS_LAST_MOD_DTTM
# SOURCE
# CMPLX_NUM
# LIVING_GBA
# FULLADDRESS
# CITY
# STATE
# ZIPCODE
# NATIONALGRID
# LATITUDE
# LONGITUDE
# ASSESSMENT_NBHD
# ASSESSMENT_SUBNBHD
# CENSUS_TRACT
# CENSUS_BLOCK
# WARD
# SQUARE
# X
# Y
# QUADRANT

# %%
dup_dc_df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
np.where(pd.isnull(dup_dc_df))
# Out:
# (array([     0,      0,      1, ..., 158956, 158956, 158956], dtype=int64),
#  array([31, 32, 13, ..., 37, 41, 43], dtype=int64))

# %%
#Selecting rows with missing price
missing_price_df= dup_dc_df[dup_dc_df['PRICE'].isnull()]

# %%
#Selecting rows with missing price
missing_price_df.head()
# Out:
#     Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 1            1       3          1      Warm Cool  Y        2.0     11      5
# 4            4       2          1      Warm Cool  Y        1.0     11      3
# 6            6       1          0      Warm Cool  Y        2.0      5      2
# 9            9       1          1  Hot Water Rad  Y        1.0      6      2
# 10          10       3          0     Forced Air  N        3.0     12      5
#
#        AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 1   1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# 4   1913.0   2012.0  ... -77.039361       Old City 2   040 D Old City 2
# 6   1917.0   1988.0  ... -77.041055       Old City 2   040 D Old City 2
# 9   1908.0   1979.0  ... -77.040081       Old City 2   040 D Old City 2
# 10  1890.0   1950.0  ... -77.040760       Old City 2   040 D Old City 2
#
# ...

# %%
missing_price_df.count()
# Out:
# Unnamed: 0            60741
# BATHRM                60741
# HF_BATHRM             60741
# HEAT                  60741
# AC                    60741
# NUM_UNITS             48796
# ROOMS                 60741
# BEDRM                 60741
# AYB                   60582
# YR_RMDL               23254
# EYB                   60741
# STORIES               48785
# SALEDATE              33972
# PRICE                     0
# QUALIFIED             60741
# SALE_NUM              60741
# GBA                   48796
# BLDG_NUM              60741
# STYLE                 48796
# STRUCT                48796
# GRADE                 48796
# CNDTN                 48796
# EXTWALL               48796
# ROOF                  48796
# INTWALL               48796
# KITCHENS              48796
# FIREPLACES            60741
# USECODE               60741
# LANDAREA              60741
# GIS_LAST_MOD_DTTM     60741
# SOURCE                60741
# CMPLX_NUM             11945
# LIVING_GBA            11945
# ...

# %%
#drop completely empty columns (all NaN/null values)
dup_dc_df.dropna(axis=1, how='all')
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
#drop completely empty rows (all NaN/null values)
dup_dc_df.dropna(axis=0, how='all')
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
dup_dc_df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
#select rows with any no missing price data
dc_df_no_missing_price = dup_dc_df[dup_dc_df['PRICE'].notnull()]
dc_df_no_missing_price.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 5           5       3          2  Hot Water Rad  Y        1.0     10      5
# 7           7       3          1  Hot Water Rad  Y        2.0      8      4
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 2  1910.0   2009.0  ... -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0  ... -77.040629       Old City 2   040 D Old City 2
# 5  1913.0      NaN  ... -77.039715       Old City 2   040 D Old City 2
# 7  1906.0   2011.0  ... -77.040129       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
dc_df_no_missing_price.count()
# Out:
# Unnamed: 0            98216
# BATHRM                98216
# HF_BATHRM             98216
# HEAT                  98216
# AC                    98216
# NUM_UNITS             57900
# ROOMS                 98216
# BEDRM                 98216
# AYB                   98104
# YR_RMDL               57674
# EYB                   98216
# STORIES               57867
# SALEDATE              98215
# PRICE                 98216
# QUALIFIED             98216
# SALE_NUM              98216
# GBA                   57900
# BLDG_NUM              98216
# STYLE                 57900
# STRUCT                57900
# GRADE                 57900
# CNDTN                 57900
# EXTWALL               57900
# ROOF                  57900
# INTWALL               57900
# KITCHENS              57899
# FIREPLACES            98216
# USECODE               98216
# LANDAREA              98216
# GIS_LAST_MOD_DTTM     98216
# SOURCE                98216
# CMPLX_NUM             40316
# LIVING_GBA            40316
# ...

# %%
#remove outliner price data

#Standard Deviation Method

meanprice = dc_df_no_missing_price['PRICE'].mean()
stdprice = dc_df_no_missing_price['PRICE'].std()
toprange = meanprice + stdprice * 1.96
botrange = meanprice - stdprice * 1.96

newdf = dc_df_no_missing_price.copy() #to not mess up the original df
newdf = newdf.drop(newdf[newdf['PRICE'] > toprange].index)
newdf = newdf.drop(newdf[newdf['PRICE'] < botrange].index)

newdf.count()
# Out:
# Unnamed: 0            97848
# BATHRM                97848
# HF_BATHRM             97848
# HEAT                  97848
# AC                    97848
# NUM_UNITS             57893
# ROOMS                 97848
# BEDRM                 97848
# AYB                   97736
# YR_RMDL               57309
# EYB                   97848
# STORIES               57860
# SALEDATE              97847
# PRICE                 97848
# QUALIFIED             97848
# SALE_NUM              97848
# GBA                   57893
# BLDG_NUM              97848
# STYLE                 57893
# STRUCT                57893
# GRADE                 57893
# CNDTN                 57893
# EXTWALL               57893
# ROOF                  57893
# INTWALL               57893
# KITCHENS              57892
# FIREPLACES            97848
# USECODE               97848
# LANDAREA              97848
# GIS_LAST_MOD_DTTM     97848
# SOURCE                97848
# CMPLX_NUM             39955
# LIVING_GBA            39955
# ...

# %%
#drop a column
newdf.drop('USECODE', axis=1)
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 14              14       3          1      Warm Cool  Y        2.0      5
# 16              16       3          1      Warm Cool  Y        1.0      8
# 19              19       3          1  Hot Water Rad  Y        2.0      9
# 20              20       3          1  Hot Water Rad  Y        1.0     14
# 22              22       1          0     Forced Air  Y        1.0      6
# 23              23       2          1     Forced Air  Y        1.0      5
# ...

# %%
#drop a column
drop_newdf= newdf.drop('NUM_UNITS', axis=1)

# %%
#drop a column
newdf.drop('NUM_UNITS', axis=1)
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  ROOMS  BEDRM     AYB  \
# 0                0       4          0      Warm Cool  Y      8      4  1910.0
# 2                2       3          1  Hot Water Rad  Y      9      5  1910.0
# 3                3       3          1  Hot Water Rad  Y      8      5  1900.0
# 5                5       3          2  Hot Water Rad  Y     10      5  1913.0
# 7                7       3          1  Hot Water Rad  Y      8      4  1906.0
# 8                8       3          1      Warm Cool  Y      7      3  1908.0
# 14              14       3          1      Warm Cool  Y      5      3  1917.0
# 16              16       3          1      Warm Cool  Y      8      3  1908.0
# 19              19       3          1  Hot Water Rad  Y      9      3  1908.0
# 20              20       3          1  Hot Water Rad  Y     14      5  1880.0
# 22              22       1          0     Forced Air  Y      6      3  1880.0
# ...

# %%
drop_newdf.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  ROOMS  BEDRM     AYB  \
# 0           0       4          0      Warm Cool  Y      8      4  1910.0
# 2           2       3          1  Hot Water Rad  Y      9      5  1910.0
# 3           3       3          1  Hot Water Rad  Y      8      5  1900.0
# 5           5       3          2  Hot Water Rad  Y     10      5  1913.0
# 7           7       3          1  Hot Water Rad  Y      8      4  1906.0
#
#    YR_RMDL   EYB  ...  LONGITUDE ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  \
# 0   1988.0  1972  ... -77.040832      Old City 2    040 D Old City 2
# 2   2009.0  1984  ... -77.040678      Old City 2    040 D Old City 2
# 3   2003.0  1984  ... -77.040629      Old City 2    040 D Old City 2
# 5      NaN  1972  ... -77.039715      Old City 2    040 D Old City 2
# 7   2011.0  1972  ... -77.040129      Old City 2    040 D Old City 2
#
#   CENSUS_TRACT  CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
#creates a table of correlation values
drop_newdf.corr()
# Out:
#               Unnamed: 0    BATHRM  HF_BATHRM     ROOMS     BEDRM       AYB  \
# Unnamed: 0      1.000000 -0.430478  -0.415857 -0.615987 -0.623737  0.424251
# BATHRM         -0.430478  1.000000   0.292055  0.709537  0.708634 -0.068478
# HF_BATHRM      -0.415857  0.292055   1.000000  0.392250  0.413532 -0.042940
# ROOMS          -0.615987  0.709537   0.392250  1.000000  0.847021 -0.222246
# BEDRM          -0.623737  0.708634   0.413532  0.847021  1.000000 -0.245185
# AYB             0.424251 -0.068478  -0.042940 -0.222246 -0.245185  1.000000
# YR_RMDL        -0.159903  0.248904   0.168670  0.205167  0.256385  0.000578
# EYB            -0.145766  0.247162   0.232679  0.166438  0.173285  0.684266
# STORIES        -0.033336  0.028315   0.032542  0.025752  0.026251 -0.003940
# PRICE          -0.227182  0.420305   0.235291  0.274292  0.283528 -0.035325
# SALE_NUM        0.017106  0.047082   0.003775 -0.008294  0.000329 -0.014639
# ...

# %%
#Selecting rows with no missing SALEDATE
nonewdf = newdf[newdf['SALEDATE'].notnull()]
nonewdf.count()
# Out:
# Unnamed: 0            97847
# BATHRM                97847
# HF_BATHRM             97847
# HEAT                  97847
# AC                    97847
# NUM_UNITS             57892
# ROOMS                 97847
# BEDRM                 97847
# AYB                   97735
# YR_RMDL               57309
# EYB                   97847
# STORIES               57859
# SALEDATE              97847
# PRICE                 97847
# QUALIFIED             97847
# SALE_NUM              97847
# GBA                   57892
# BLDG_NUM              97847
# STYLE                 57892
# STRUCT                57892
# GRADE                 57892
# CNDTN                 57892
# EXTWALL               57892
# ROOF                  57892
# INTWALL               57892
# KITCHENS              57891
# FIREPLACES            97847
# USECODE               97847
# LANDAREA              97847
# GIS_LAST_MOD_DTTM     97847
# SOURCE                97847
# CMPLX_NUM             39955
# LIVING_GBA            39955
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#boxplot showing stats for each characteristic
sns.boxplot(data=newdf)

# %%
#Selecting rows with no missing SALEDATE
nonewdf = newdf[newdf['ZIPCODE'].notnull()]
nonewdf.count()
# Out:
# Unnamed: 0            97848
# BATHRM                97848
# HF_BATHRM             97848
# HEAT                  97848
# AC                    97848
# NUM_UNITS             57893
# ROOMS                 97848
# BEDRM                 97848
# AYB                   97736
# YR_RMDL               57309
# EYB                   97848
# STORIES               57860
# SALEDATE              97847
# PRICE                 97848
# QUALIFIED             97848
# SALE_NUM              97848
# GBA                   57893
# BLDG_NUM              97848
# STYLE                 57893
# STRUCT                57893
# GRADE                 57893
# CNDTN                 57893
# EXTWALL               57893
# ROOF                  57893
# INTWALL               57893
# KITCHENS              57892
# FIREPLACES            97848
# USECODE               97848
# LANDAREA              97848
# GIS_LAST_MOD_DTTM     97848
# SOURCE                97848
# CMPLX_NUM             39955
# LIVING_GBA            39955
# ...

# %%
#make a scatterplot
sns.lmplot(x='ZIPCODE', y='PRICE', data=newdf)

# %%
#make a scatterplot
sns.lmplot(x='ROOMS', y='PRICE', data=newdf, 
           fit_reg=False)

# %%
#add more details to scatterplot
sns.lmplot(x='BATHRM', y='PRICE', data=newdf, 
           fit_reg=False)

# %%
#make a scatterplot
sns.lmplot(x='GBA', y='PRICE', data=newdf, 
           fit_reg=False)

# %%
#change size of plot
plt.subplots(figsize=(13,7))

#violin plot shows the distribution of attack power for each type
sns.violinplot(x='BATHRM', y='PRICE', data=drop_newdf)

# %%
#compare number of rooms to home price
plt.scatter(drop_newdf['GBA'], drop_newdf['PRICE']) 
plt.xlabel("Average number of GBA") 
plt.ylabel("Housing Price") 
plt.title("Relationship between GBA and Price") 
plt.show()

# %%
#creates a table of correlation values
newdf.corr()
# Out:
#               Unnamed: 0    BATHRM  HF_BATHRM  NUM_UNITS     ROOMS     BEDRM  \
# Unnamed: 0      1.000000 -0.430478  -0.415857  -0.016744 -0.615987 -0.623737
# BATHRM         -0.430478  1.000000   0.292055   0.384145  0.709537  0.708634
# HF_BATHRM      -0.415857  0.292055   1.000000  -0.177617  0.392250  0.413532
# NUM_UNITS      -0.016744  0.384145  -0.177617   1.000000  0.538629  0.340222
# ROOMS          -0.615987  0.709537   0.392250   0.538629  1.000000  0.847021
# BEDRM          -0.623737  0.708634   0.413532   0.340222  0.847021  1.000000
# AYB             0.424251 -0.068478  -0.042940  -0.111096 -0.222246 -0.245185
# YR_RMDL        -0.159903  0.248904   0.168670  -0.030131  0.205167  0.256385
# EYB            -0.145766  0.247162   0.232679  -0.124927  0.166438  0.173285
# STORIES        -0.033336  0.028315   0.032542   0.009912  0.025752  0.026251
# PRICE          -0.227182  0.420305   0.235291   0.001425  0.274292  0.283528
# ...

# %%
corr = newdf.corr() # df is the pandas dataframe
c1 = corr.abs().unstack()
c1.sort_values(ascending = False)
# Out:
# Y             Y               1.000000
# GBA           GBA             1.000000
# LONGITUDE     LONGITUDE       1.000000
# LATITUDE      LATITUDE        1.000000
# ZIPCODE       ZIPCODE         1.000000
# LIVING_GBA    LIVING_GBA      1.000000
# CMPLX_NUM     CMPLX_NUM       1.000000
# LANDAREA      LANDAREA        1.000000
# USECODE       USECODE         1.000000
# FIREPLACES    FIREPLACES      1.000000
# KITCHENS      KITCHENS        1.000000
# BLDG_NUM      BLDG_NUM        1.000000
# SALE_NUM      SALE_NUM        1.000000
# X             X               1.000000
# PRICE         PRICE           1.000000
# STORIES       STORIES         1.000000
# EYB           EYB             1.000000
# YR_RMDL       YR_RMDL         1.000000
# AYB           AYB             1.000000
# BEDRM         BEDRM           1.000000
# ROOMS         ROOMS           1.000000
# NUM_UNITS     NUM_UNITS       1.000000
# HF_BATHRM     HF_BATHRM       1.000000
# BATHRM        BATHRM          1.000000
# ...

# %%
corr_matrix = drop_newdf.corr().abs()
# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

to_drop = [column for column in upper.columns if any(upper[column] < 0.30)]

# %%
corr_matrix
# Out:
#               Unnamed: 0    BATHRM  HF_BATHRM     ROOMS     BEDRM       AYB  \
# Unnamed: 0      1.000000  0.430478   0.415857  0.615987  0.623737  0.424251
# BATHRM          0.430478  1.000000   0.292055  0.709537  0.708634  0.068478
# HF_BATHRM       0.415857  0.292055   1.000000  0.392250  0.413532  0.042940
# ROOMS           0.615987  0.709537   0.392250  1.000000  0.847021  0.222246
# BEDRM           0.623737  0.708634   0.413532  0.847021  1.000000  0.245185
# AYB             0.424251  0.068478   0.042940  0.222246  0.245185  1.000000
# YR_RMDL         0.159903  0.248904   0.168670  0.205167  0.256385  0.000578
# EYB             0.145766  0.247162   0.232679  0.166438  0.173285  0.684266
# STORIES         0.033336  0.028315   0.032542  0.025752  0.026251  0.003940
# PRICE           0.227182  0.420305   0.235291  0.274292  0.283528  0.035325
# SALE_NUM        0.017106  0.047082   0.003775  0.008294  0.000329  0.014639
# ...

# %%
#use this library to build a statistical test for linear regression
import statsmodels.formula.api as smf

# %%
#OLS is Ordinary Least Squares, the most common type of linear regression
#the fit function uses the predictive values to calculate the best linear regression line
result = smf.ols('PRICE ~ BATHRM + ROOMS + YR_RMDL + GBA + LANDAREA', data=drop_newdf).fit()

# %%
#OLS is Ordinary Least Squares, the most common type of linear regression
#the fit function uses the predictive values to calculate the best linear regression line
result = smf.ols('PRICE ~ BATHRM + ROOMS + YR_RMDL + GBA + LANDAREA', data=drop_newdf).fit()

# %%
#the summary will show the calculated values (slopes and y-intercept) for the linear regression formula
#the closer to 1 the r-squared value is, the better the fit of the linear regression line
#the p-value shows how statistically significant a predictive feature could be the model

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     5174.
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):               0.00
# Time:                        03:27:49   Log-Likelihood:            -4.8004e+05
# No. Observations:               33213   AIC:                         9.601e+05
# Df Residuals:                   33207   BIC:                         9.602e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3.515e+06   3.07e+05    -11.463      0.000   -4.12e+06   -2.91e+06
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn #library for predictive modeling

# %matplotlib inline

# %%
drop_newdf.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  ROOMS  BEDRM     AYB  \
# 0           0       4          0      Warm Cool  Y      8      4  1910.0
# 2           2       3          1  Hot Water Rad  Y      9      5  1910.0
# 3           3       3          1  Hot Water Rad  Y      8      5  1900.0
# 5           5       3          2  Hot Water Rad  Y     10      5  1913.0
# 7           7       3          1  Hot Water Rad  Y      8      4  1906.0
#
#    YR_RMDL   EYB  ...  LONGITUDE ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  \
# 0   1988.0  1972  ... -77.040832      Old City 2    040 D Old City 2
# 2   2009.0  1984  ... -77.040678      Old City 2    040 D Old City 2
# 3   2003.0  1984  ... -77.040629      Old City 2    040 D Old City 2
# 5      NaN  1972  ... -77.039715      Old City 2    040 D Old City 2
# 7   2011.0  1972  ... -77.040129      Old City 2    040 D Old City 2
#
#   CENSUS_TRACT  CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
from sklearn.linear_model import LinearRegression

#make dataframe that only contains predictive features
X = drop_newdf.drop('PRICE', axis = 1)
#assign linear regression function to a variable
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#compare number of rooms to home price
plt.scatter(drop_newdf['GBA'], drop_newdf['PRICE']) 
plt.xlabel("Average number of GBA") 
plt.ylabel("Housing Price") 
plt.title("Relationship between GBA and Price") 
plt.show()

# %%
#same as statsmodel; fit will calculate linear regression model based on values of predictive features
lm.fit(X, drop_newdf['PRICE'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-162-a9e22d0fc1a3> in <module>
#       1 #same as statsmodel; fit will calculate linear regression model based on values of predictive features
# ----> 2 lm.fit(X, drop_newdf['PRICE'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
#y-intercept for the linear regression formula
print('Estimated intercept coefficient:', lm.intercept_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-163-5020744a2d95> in <module>
#       1 #y-intercept for the linear regression formula
# ----> 2 print('Estimated intercept coefficient:', lm.intercept_)
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'
